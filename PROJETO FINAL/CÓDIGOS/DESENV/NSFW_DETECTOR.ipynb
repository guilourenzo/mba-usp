# %%
import cv2
import glob
import numpy as np
import matplotlib.pyplot as plt
from nsfw_detector import predict

# %%
model = predict.load_model('./MODELOS/nsfw_mobilenet2.224x224.h5')
results = {}
# Out:
# WARNING:tensorflow:Error in loading the saved optimizer state. As a result, your model is starting with a freshly initialized optimizer.

# %% [markdown]
# # IMAGENS: NORMAIS

# %%
path = '/mnt/d/NUDENET/NudeNet_classifier_dataset_v1/nude_sexy_safe_v1_x320/testing/safe/*.jpg'
files = glob.glob(path)
imagem = np.random.choice(files)
arquivo = imagem.replace('/mnt/d/NUDENET/NudeNet_classifier_dataset_v1/nude_sexy_safe_v1_x320/testing/safe/', '').replace('.jpg', '')
imagem
# Out:
# '/mnt/d/NUDENET/NudeNet_classifier_dataset_v1/nude_sexy_safe_v1_x320/testing/safe/335474F7-4F47-457B-B11F-814A59794686.jpg'

# %%
original_image = cv2.cvtColor(cv2.imread(imagem),cv2.COLOR_BGR2RGB)

figure_size = 10
plt.figure(figsize=(figure_size,figure_size))
plt.imshow(original_image)
# plt.title('Imagem Original')
plt.xticks([]), plt.yticks([])
plt.show()

# %%
safe = predict.classify(model, imagem)
results[arquivo] = safe[imagem]
safe
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-5-60e830ded65c> in <module>
# ----> 1 safe = predict.classify(model, imagem)
#       2 results[arquivo] = safe[imagem]
#       3 safe
#
# NameError: name 'model' is not defined

# %% [markdown]
# # IMAGENS: SEXY

# %%
path = '/mnt/d/NUDENET/NudeNet_classifier_dataset_v1/nude_sexy_safe_v1_x320/testing/sexy/*.jpg'
files = glob.glob(path)
imagem = np.random.choice(files)
arquivo = imagem.replace('/mnt/d/NUDENET/NudeNet_classifier_dataset_v1/nude_sexy_safe_v1_x320/testing/sexy/', '').replace('.jpg', '')
imagem
# Out:
# '/mnt/d/NUDENET/NudeNet_classifier_dataset_v1/nude_sexy_safe_v1_x320/testing/sexy/6EF1D34A-FF40-4FF3-9D6E-CAB999A67652.jpg'

# %%
# original_image = cv2.cvtColor(cv2.imread(imagem),cv2.COLOR_BGR2RGB)

# figure_size = 10
# plt.figure(figsize=(figure_size,figure_size))
# plt.imshow(original_image)
# plt.title('Imagem Original')
# plt.xticks([]), plt.yticks([])
# plt.show()

# %%
sexy = predict.classify(model, imagem)
results[arquivo] = sexy[imagem]
sexy
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-6518d4a2c8c1> in <module>
# ----> 1 sexy = predict.classify(model, imagem)
#       2 results[arquivo] = sexy[imagem]
#       3 sexy
#
# NameError: name 'model' is not defined

# %% [markdown]
# # IMAGENS: NUDE

# %%
path = '/mnt/d/NUDENET/NudeNet_classifier_dataset_v1/nude_sexy_safe_v1_x320/testing/nude/*.jpg'
files = glob.glob(path)
imagem = np.random.choice(files)
arquivo = imagem.replace('/mnt/d/NUDENET/NudeNet_classifier_dataset_v1/nude_sexy_safe_v1_x320/testing/nude/', '').replace('.jpg', '')
imagem
# Out:
# '/mnt/d/NUDENET/NudeNet_classifier_dataset_v1/nude_sexy_safe_v1_x320/testing/nude/5A9762F7-6F43-4891-98E0-414CFCD49245.jpg'

# %%
# original_image = cv2.cvtColor(cv2.imread(imagem),cv2.COLOR_BGR2RGB)

# figure_size = 10
# plt.figure(figsize=(figure_size,figure_size))
# plt.imshow(original_image)
# plt.title('Imagem Original')
# plt.xticks([]), plt.yticks([])
# plt.show()

# %%
nude = predict.classify(model, imagem)
results[arquivo] = nude[imagem]
nude
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-11-95e8ea8094eb> in <module>
# ----> 1 nude = predict.classify(model, imagem)
#       2 results[arquivo] = nude[imagem]
#       3 nude
#
# NameError: name 'model' is not defined

# %%
results
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-12-100f62972f2f> in <module>
# ----> 1 results
#
# NameError: name 'results' is not defined

# %%
for k, v in results.items():
    if (results[k]['porn'] > 0.2) | (results[k]['sexy'] > 0.2) | (results[k]['hentai'] > 0.5):
        print(f'{k}: NUDEZ ENCONTRADA')
    else:
        print(f'{k}: IMAGEM LIVRE')
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-13-4457cbd0f3e1> in <module>
# ----> 1 for k, v in results.items():
#       2     if (results[k]['porn'] > 0.2) | (results[k]['sexy'] > 0.2) | (results[k]['hentai'] > 0.5):
#       3         print(f'{k}: NUDEZ ENCONTRADA')
#       4     else:
#       5         print(f'{k}: IMAGEM LIVRE')
#
# NameError: name 'results' is not defined
