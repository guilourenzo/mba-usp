# %%
from scipy import stats
from math import sqrt
from scipy.stats import norm

# %%
# Take 10,000 samples out of the binomial distribution: n_defaults
pn_binomial = np.random.binomial(100, 0.05, size=10000)

# Compute bin edges: bins
bins = np.arange(0, max(pn_binomial) + 1.5) - 0.5

# Generate histogram
plt.hist(pn_binomial, density=True, bins=bins)

# Label axes
plt.xlabel('x')
plt.ylabel('y')

# Show the plot
plt.show()

# %%
# Take 10,000 samples out of the binomial distribution: n_defaults
_2pn_binomial = np.random.binomial((2*100), 0.05, size=10000)

# Compute bin edges: bins
bins = np.arange(0, max(_2pn_binomial) + 1.5) - 0.5

# Generate histogram
plt.hist(_2pn_binomial, density=True, bins=bins, alpha=0.7)

# Label axes
plt.xlabel('x')
plt.ylabel('y')

# Show the plot
plt.show()

# %%
# Compute bin edges: bins
bins_pn = np.arange(0, max(pn_binomial) + 1.5) - 0.5
bins_2pn = np.arange(0, max(_2pn_binomial) + 1.5) - 0.5

# Generate histogram
plt.hist(pn_binomial, density=True, bins=bins_pn, alpha=0.6)

# Generate histogram
plt.hist(_2pn_binomial, density=True, bins=bins_2pn, alpha=0.8)

# Label axes
plt.xlabel('x')
plt.ylabel('y')

# Show the plot
plt.show()

# %%
var_pn = np.var(pn_binomial)
var_2pn = np.var(_2pn_binomial)

print('Variância pn:', var_pn,'\nVariância 2pn:', var_2pn)
# Out:
# Variância pn: 4.822441240000001
# Variância 2pn: 9.56694375

# %% [markdown]
# ------

# %%
# Draw 10,000 samples out of Poisson distribution: samples_poisson
samples_poisson = np.random.poisson(4, size=20)

# Print the mean and standard deviation
print('Poisson Mean:', np.mean(samples_poisson))
print('Poisson Std:', np.std(samples_poisson))
# Out:
# Poisson Mean: 3.8
# Poisson Std: 1.8055470085267789

# %%
# Compara a verossimilhança da amostra para diferentes valores dos parâmetros mu
def L_amostra(x, mu, sd):
    L = 0
    for i in x:
        L += norm.pdf(i, mu, sd) # cálculo da função de verossimilhança da amostra
   
#    print ("média = ", mu, "desvio padrão = ", sd,"L:", L)
    return L


mu = np.linspace(4, 6, 8, 10)
L1 = L_amostra(x,mu,np.std(x)) # para a amostra de valores em x e para o desvio padrão suposto conhecido e igual ao amostral, calcula a verossimilhança para diversos valores de média
L2 = L_amostra(x,mu,4) # para a amostra de valores em x e para o desvio padrão sendo igual ao amostral, calcula a verossimilhança para diversos valores de média

plt.plot(mu,L1, label = r'$sigma^2=38^2$')
plt.plot(mu,L2, label = r'$sigma^2=20^2$')
plt.xlabel(r'$\mu$')
plt.ylabel(r'$L(\mu,\sigma^2)$')
plt.title(r'Média do ENEM: $N(\mu,\sigma^2)$')
plt.legend()
plt.show()
