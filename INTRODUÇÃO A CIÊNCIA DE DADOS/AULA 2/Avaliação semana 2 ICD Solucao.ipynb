# %% [markdown]
# # Soluções dos exercícios da aula 2

# %% [markdown]
# ### **Exercício 1**:  Mude a função seno para cosseno (no exemplo da aula) e verifique qual grau do polinômio mais adequado para 20 observações (10 no conjunto de teste e 10 no conjunto de treinamento). Considere o código abaixo para gerar os dados.

# %% [markdown]
# - (a) 1
# - (b) 2
# - (c) 4
# - (d) 8
# - (e) 9

# %% [markdown]
# Solução: **(c) 4**

# %%
import numpy as np
from matplotlib import pyplot as plt, rcParams

np.random.seed(101)

fig = plt.figure(figsize=(8, 6))

def function(x):
    y = np.cos(2 * np.pi * x)
    return y

N_train = 10
x_train=np.linspace(0, 1,N_train)
y_train = function(x_train) + np.random.normal(0,0.1, N_train)
plt.scatter(x_train, y_train, facecolor="none", edgecolor="b", s=100, label="training data")

# test set
N_test = 10
x_test=np.linspace(0, 1,N_test)
y_test = function(x_test) +  np.random.normal(0,0.1, N_test)

# Theoretical curves
xt=np.linspace(0, 1,100)
yt = function(xt)

plt.plot(xt,yt, '-r')
plt.show(True)

# %%
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures

def rmse(a, b):
    return np.sqrt(np.mean(np.square(a - b)))

training_errors = []
test_errors = []
degree = []
fig = plt.figure(figsize=(8, 6))
for M in np.arange(1,10):    
    poly = PolynomialFeatures(degree=M)
    X_train = poly.fit_transform(x_train[:,np.newaxis])
    clf = linear_model.LinearRegression()
    clf.fit(X_train,y_train)
    Y_pred = clf.predict(X_train)
    error_train = rmse(Y_pred,y_train)
    training_errors.append(error_train)
    
    X_test=poly.fit_transform(x_test[:,np.newaxis])
    Y_pred2 = clf.predict(X_test)
    error_test = rmse(Y_pred2, y_test)
    test_errors.append(error_test)
    degree.append(M)
plt.plot(degree, training_errors, 'b-o', label = 'Training error')
plt.plot(degree, test_errors, 'r-o', label= 'Test error')
plt.xlabel("Degree", fontsize = 15)
plt.ylabel("RMSE", fontsize = 15)
plt.legend(fontsize = 15)
plt.show(True)

# %% [markdown]
# <hr>

# %% [markdown]
# ### **Exercício 2**:  Mude a função seno para $x^4$ (no exemplo da aula) e verifique qual grau do polinômio mais adequado para 20 observações (10 no conjunto de teste e 10 no conjunto de treinamento). Use o código abaixo para gerar os dados.

# %%
import numpy as np
from matplotlib import pyplot as plt, rcParams

np.random.seed(101)

fig = plt.figure(figsize=(8, 6))

def function(x):
    y = x**4
    return y

N_train = 10
x_train=np.linspace(0, 1,N_train)
y_train = function(x_train) + np.random.normal(0,0.1, N_train)
plt.scatter(x_train, y_train, facecolor="none", edgecolor="b", s=100, label="training data")

# test set
N_test = 10
x_test=np.linspace(0, 1,N_test)
y_test = function(x_test) +  np.random.normal(0,0.1, N_test)

# Theoretical curves
xt=np.linspace(0, 1,100)
yt = function(xt)

plt.plot(xt,yt, '-r')
plt.show(True)

# %%
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures

def rmse(a, b):
    return np.sqrt(np.mean(np.square(a - b)))

training_errors = []
test_errors = []
degree = []
fig = plt.figure(figsize=(8, 6))
for M in np.arange(1,10):    
    poly = PolynomialFeatures(degree=M)
    X_train = poly.fit_transform(x_train[:,np.newaxis])
    clf = linear_model.LinearRegression()
    clf.fit(X_train,y_train)
    Y_pred = clf.predict(X_train)
    error_train = rmse(Y_pred,y_train)
    training_errors.append(error_train)
    
    X_test=poly.fit_transform(x_test[:,np.newaxis])
    Y_pred2 = clf.predict(X_test)
    error_test = rmse(Y_pred2, y_test)
    test_errors.append(error_test)
    degree.append(M)
plt.plot(degree, training_errors, 'b-o', label = 'Training error')
plt.plot(degree, test_errors, 'r-o', label= 'Test error')
plt.xlabel("Degree", fontsize = 15)
plt.ylabel("RMSE", fontsize = 15)
plt.legend(fontsize = 15)
plt.show(True)

# %% [markdown]
# (a) 1, (b) 3, (c) 4, (d) 2, (e) 8

# %% [markdown]
# Solução: (d) 2

# %% [markdown]
# <hr>

# %% [markdown]
# ### **Exercício 3**: Considere 100 pontos (50 no conjunto de treinamento e 50 no conjunto de teste) gerados a partir da função cosseno com erro. Qual o grau mais adequado do polinômio? Considere o código abaixo.

# %% [markdown]
# - (a) 4
# - (b) 5
# - (c) 8
# - (d) 12
# - (e) 14

# %% [markdown]
# Solução: (a) 4

# %%
import numpy as np
from matplotlib import pyplot as plt, rcParams

np.random.seed(101)

fig = plt.figure(figsize=(8, 6))

def function(x):
    y = np.cos(2 * np.pi * x)
    return y

N_train = 50
x_train=np.linspace(0, 1,N_train)
y_train = function(x_train) + np.random.normal(0,0.1, N_train)
plt.scatter(x_train, y_train, facecolor="none", edgecolor="b", s=100, label="training data")

# test set
N_test = 50
x_test=np.linspace(0, 1,N_test)
y_test = function(x_test) +  np.random.normal(0,0.1, N_test)

# Theoretical curves
xt=np.linspace(0, 1,100)
yt = function(xt)

plt.plot(xt,yt, '-r')
plt.show(True)

# %%
from sklearn import linear_model
from sklearn.preprocessing import PolynomialFeatures

def rmse(a, b):
    return np.sqrt(np.mean(np.square(a - b)))

training_errors = []
test_errors = []
degree = []
fig = plt.figure(figsize=(8, 6))
for M in np.arange(1,15):    
    poly = PolynomialFeatures(degree=M)
    X_train = poly.fit_transform(x_train[:,np.newaxis])
    clf = linear_model.LinearRegression()
    clf.fit(X_train,y_train)
    Y_pred = clf.predict(X_train)
    error_train = rmse(Y_pred,y_train)
    training_errors.append(error_train)
    
    X_test=poly.fit_transform(x_test[:,np.newaxis])
    Y_pred2 = clf.predict(X_test)
    error_test = rmse(Y_pred2, y_test)
    test_errors.append(error_test)
    degree.append(M)
plt.plot(degree, training_errors, 'b-o', label = 'Training error')
plt.plot(degree, test_errors, 'r-o', label= 'Test error')
plt.xlabel("Degree", fontsize = 15)
plt.ylabel("RMSE", fontsize = 15)
plt.legend(fontsize = 15)
plt.show(True)

# %% [markdown]
# <hr>

# %% [markdown]
# ### **Exercício 4**: Considerando a base Vehicle, encontre o melhor número de vizinhos. Qual é a acurácia aproximada usando validação cruzada com 10 folds? Repita o que foi feito na aula para a base iris.

# %% [markdown]
# - (a) 0,6
# - (b) 0,9
# - (c) 0,2
# - (d) 1,0
# - (e) 0,3

# %% [markdown]
# Solução: **(a) 0.6**

# %%
import random
random.seed(1)
# Pandas is used for data manipulation
import pandas as pd
import matplotlib.pyplot as plt

# CSV file
data = pd.read_csv('data/Vehicle.csv', header=(0))
data = data.dropna(axis='rows') #remove NaN

data = data.to_numpy()
nrow,ncol = data.shape
y = data[:,-1]
X = data[:,0:ncol-1]

from sklearn.model_selection import train_test_split

p = 0.2 # fracao de elementos no conjunto de teste
x_train, x_test, y_train, y_test = train_test_split(X, y, test_size = p)

from sklearn.model_selection import cross_validate
from sklearn.neighbors import KNeighborsClassifier

nkf = 10 #number of folds
vk = []
vscore = []
for k in range(1, 30):
    model = KNeighborsClassifier(n_neighbors=k, metric = 'euclidean')
    cv = cross_validate(model, x_train, y_train, cv=nkf)
    print('k:', k, 'accurace:', cv['test_score'].mean())
    vscore.append(cv['test_score'].mean())
    vk.append(k)

best_k = np.argmax(vscore)+1
print('Melhor k:', best_k)
plt.figure(figsize=(10,5))
plt.plot(vk, vscore, '-bo')
plt.xlabel('k', fontsize = 15)
plt.ylabel('Accuracy', fontsize = 15)
plt.show()

from sklearn.metrics import accuracy_score
model = KNeighborsClassifier(n_neighbors=best_k, metric = 'euclidean')
model.fit(x_train, y_train)
y_pred = model.predict(x_test)
print('Accuracy:', accuracy_score(y_pred, y_test))
# Out:
# k: 1 accurace: 0.6630951843896074
# k: 2 accurace: 0.6393991157904966
# k: 3 accurace: 0.6616613514617102
# k: 4 accurace: 0.6688372540922451
# k: 5 accurace: 0.6586755827928481
# k: 6 accurace: 0.6438114877831257
# k: 7 accurace: 0.6587840846916314
# k: 8 accurace: 0.6349860208374543
# k: 9 accurace: 0.6306834520723517
# k: 10 accurace: 0.6263336595330717
# k: 11 accurace: 0.6262956028969313
# k: 12 accurace: 0.6085542700355465
# k: 13 accurace: 0.6069106339957965
# k: 14 accurace: 0.6143978722985861
# k: 15 accurace: 0.6039694864436248
# k: 16 accurace: 0.6157128216161694
# k: 17 accurace: 0.6140891971206511
# k: 18 accurace: 0.6065380201989357
# k: 19 accurace: 0.6036168552725792
# k: 20 accurace: 0.6095896071837973
# k: 21 accurace: 0.6082681801409138
# k: 22 accurace: 0.5905107397215273
# k: 23 accurace: 0.5905759796691965
# k: 24 accurace: 0.5936043162471762
# k: 25 accurace: 0.587588967508424
# k: 26 accurace: 0.5876567811951634
# k: 27 accurace: 0.5770533232465896
# k: 28 accurace: 0.5758203576398409
# k: 29 accurace: 0.5845360213579858
# Melhor k: 4
# Accuracy: 0.6176470588235294

# %% [markdown]
# <hr>

# %% [markdown]
# ### **Exercíco 5** - Quais são os principais igredientes em um problema de aprendizado supervisionado?

# %% [markdown]
# (a) conjunto de dados, modelo e função de custo.<br>
# (b) conjunto de dados, normalização e projeção.<br>
# (c) modelo, função de custo e seleção de atributos.<br>
# (d) conjunto de dados, validação cruzada e modelo <br>
# (e) nenhuma das alternativas.

# %% [markdown]
# Solução: **(a)**
